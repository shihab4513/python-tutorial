# %%
print("Hello World")
a=7+9
print(a)
# Out:
# Hello World
# 16

# %%
#Assigning multiple variable
a,b,c=4,5,6
print(a,b,c)
# Out:
# 4 5 6

# %%
#Assigning same value in multiple variable
a=b=c="Orange"
x=y=z=7
print(x,y,z)
print(a,b,c)
# Out:
# 7 7 7
# Orange Orange Orange

# %%
#unpacking collection values from tuple and list
fruites=["apple","banana","orange"]
a,b,c=fruites
print(a,b,c)
# Out:
# apple banana orange

# %%
#global variable
gx=9

def g_test():
    gx=8
    global gy
    gy=89
    print(gx)

g_test()
print(gy)
# Out:
# 8
# 89

# %%
#
